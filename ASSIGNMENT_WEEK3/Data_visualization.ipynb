# %%
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# dataset loading 
df = pd.read_csv("ai_job_dataset.csv")

plt.figure(figsize=(14, 10))


plt.subplot(2, 2, 1)
levels = df["experience_level"].unique()
salary_data = [df[df["experience_level"] == lvl]["salary_usd"] for lvl in levels]
plt.boxplot(salary_data, labels=levels, patch_artist=True)
plt.title("Salary Distribution by Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Salary (USD)")


plt.subplot(2, 2, 2)
sizes = df["company_size"].unique()
salary_data_size = [df[df["company_size"] == size]["salary_usd"] for size in sizes]
plt.boxplot(salary_data_size, labels=sizes, patch_artist=True)
plt.title("Salary Distribution by Company Size")
plt.xlabel("Company Size")
plt.ylabel("Salary (USD)")


plt.subplot(2, 2, 3)
plt.hist(df["remote_ratio"], bins=10, color="skyblue", edgecolor="black")
plt.title("Remote Ratio Distribution")
plt.xlabel("Remote Ratio (%)")
plt.ylabel("Number of Jobs")


skill_list = df["required_skills"].str.split(", ").sum()
skill_counts = Counter(skill_list)
top_skills = skill_counts.most_common(10)
skills, counts = zip(*top_skills)

plt.subplot(2, 2, 4)
plt.barh(skills, counts, color="red")
plt.title("Top 10 Required Skills")
plt.xlabel("Frequency")
plt.gca().invert_yaxis()  

plt.tight_layout()
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22520\1778143149.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(salary_data, labels=levels, patch_artist=True)
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22520\1778143149.py:23: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(salary_data_size, labels=sizes, patch_artist=True)
